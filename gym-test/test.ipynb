# %%
import gym
from gym import envs

# %%
import gym
env = gym.make("MountainCar-v0")
MAX_NUM_EPISODES = 5000

for episode in range(MAX_NUM_EPISODES):
    done = False
    obs = env.reset()
    total_reward = 0.0 # To keep track of the total reward obtained in each episode
    step = 0
    while not done:
        env.render()
        action = env.action_space.sample()# Sample random action. This will be replaced by our agent's action when we start developing the agent algorithms
        next_state, reward, done, info = env.step(action) # Send the action to the environment and receive the next_state, reward and whether done or not
        total_reward += reward
        step += 1
        obs = next_state

    print("\n Episode #{} ended in {} steps. total_reward={}".format(episode, step+1, total_reward))
env.close()
# Out:
#  Episode #0 ended in 201 steps. total_reward=-200.0
#
#  Episode #1 ended in 201 steps. total_reward=-200.0
#
#  Episode #2 ended in 201 steps. total_reward=-200.0
#
#  Episode #3 ended in 201 steps. total_reward=-200.0
#
#  Episode #4 ended in 201 steps. total_reward=-200.0
#
#  Episode #5 ended in 201 steps. total_reward=-200.0
#
#  Episode #6 ended in 201 steps. total_reward=-200.0
#
#  Episode #7 ended in 201 steps. total_reward=-200.0
#
#  Episode #8 ended in 201 steps. total_reward=-200.0
#
#  Episode #9 ended in 201 steps. total_reward=-200.0
#
#  Episode #10 ended in 201 steps. total_reward=-200.0
#
#  Episode #11 ended in 201 steps. total_reward=-200.0
#
#  Episode #12 ended in 201 steps. total_reward=-200.0
#
#  Episode #13 ended in 201 steps. total_reward=-200.0
#
#  Episode #14 ended in 201 steps. total_reward=-200.0
#
#  Episode #15 ended in 201 steps. total_reward=-200.0
#
#  Episode #16 ended in 201 steps. total_reward=-200.0
#
#  Episode #17 ended in 201 steps. total_reward=-200.0
#
#  Episode #18 ended in 201 steps. total_reward=-200.0
#
#  Episode #19 ended in 201 steps. total_reward=-200.0
#
#  Episode #20 ended in 201 steps. total_reward=-200.0
#
#  Episode #21 ended in 201 steps. total_reward=-200.0
#
#  Episode #22 ended in 201 steps. total_reward=-200.0
#
#  Episode #23 ended in 201 steps. total_reward=-200.0
#
#  Episode #24 ended in 201 steps. total_reward=-200.0
#
#  Episode #25 ended in 201 steps. total_reward=-200.0
#
#  Episode #26 ended in 201 steps. total_reward=-200.0
#
#  Episode #27 ended in 201 steps. total_reward=-200.0
#
#  Episode #28 ended in 201 steps. total_reward=-200.0
#
#  Episode #29 ended in 201 steps. total_reward=-200.0
#
#  Episode #30 ended in 201 steps. total_reward=-200.0
#
#  Episode #31 ended in 201 steps. total_reward=-200.0
#
#  Episode #32 ended in 201 steps. total_reward=-200.0
#
#  Episode #33 ended in 201 steps. total_reward=-200.0
#
#  Episode #34 ended in 201 steps. total_reward=-200.0
#
#  Episode #35 ended in 201 steps. total_reward=-200.0
#
#  Episode #36 ended in 201 steps. total_reward=-200.0
#
#  Episode #37 ended in 201 steps. total_reward=-200.0
#
#  Episode #38 ended in 201 steps. total_reward=-200.0
#
#  Episode #39 ended in 201 steps. total_reward=-200.0
#
#  Episode #40 ended in 201 steps. total_reward=-200.0
#
#  Episode #41 ended in 201 steps. total_reward=-200.0
#
#  Episode #42 ended in 201 steps. total_reward=-200.0
#
#  Episode #43 ended in 201 steps. total_reward=-200.0
#
#  Episode #44 ended in 201 steps. total_reward=-200.0
#
#  Episode #45 ended in 201 steps. total_reward=-200.0
#
#  Episode #46 ended in 201 steps. total_reward=-200.0
#
#  Episode #47 ended in 201 steps. total_reward=-200.0
#
#  Episode #48 ended in 201 steps. total_reward=-200.0
#
#  Episode #49 ended in 201 steps. total_reward=-200.0
#
#  Episode #50 ended in 201 steps. total_reward=-200.0
#
#  Episode #51 ended in 201 steps. total_reward=-200.0
#
#  Episode #52 ended in 201 steps. total_reward=-200.0
#
#  Episode #53 ended in 201 steps. total_reward=-200.0
#
#  Episode #54 ended in 201 steps. total_reward=-200.0
#
#  Episode #55 ended in 201 steps. total_reward=-200.0
#
#  Episode #56 ended in 201 steps. total_reward=-200.0
#
#  Episode #57 ended in 201 steps. total_reward=-200.0
#
#  Episode #58 ended in 201 steps. total_reward=-200.0
#
#  Episode #59 ended in 201 steps. total_reward=-200.0
#
#  Episode #60 ended in 201 steps. total_reward=-200.0
#
#  Episode #61 ended in 201 steps. total_reward=-200.0
#
#  Episode #62 ended in 201 steps. total_reward=-200.0
#
#  Episode #63 ended in 201 steps. total_reward=-200.0
#
#  Episode #64 ended in 201 steps. total_reward=-200.0
#
#  Episode #65 ended in 201 steps. total_reward=-200.0
#
#  Episode #66 ended in 201 steps. total_reward=-200.0
#
#  Episode #67 ended in 201 steps. total_reward=-200.0
#
#  Episode #68 ended in 201 steps. total_reward=-200.0
#
#  Episode #69 ended in 201 steps. total_reward=-200.0
#
#  Episode #70 ended in 201 steps. total_reward=-200.0
#
#  Episode #71 ended in 201 steps. total_reward=-200.0
#
#  Episode #72 ended in 201 steps. total_reward=-200.0
#
#  Episode #73 ended in 201 steps. total_reward=-200.0
#
#  Episode #74 ended in 201 steps. total_reward=-200.0
#
#  Episode #75 ended in 201 steps. total_reward=-200.0
#
#  Episode #76 ended in 201 steps. total_reward=-200.0
#
#  Episode #77 ended in 201 steps. total_reward=-200.0
#
#  Episode #78 ended in 201 steps. total_reward=-200.0
#
#  Episode #79 ended in 201 steps. total_reward=-200.0
#
#  Episode #80 ended in 201 steps. total_reward=-200.0
#
#  Episode #81 ended in 201 steps. total_reward=-200.0
#
#  Episode #82 ended in 201 steps. total_reward=-200.0
#
#  Episode #83 ended in 201 steps. total_reward=-200.0
#
#  Episode #84 ended in 201 steps. total_reward=-200.0
#
#  Episode #85 ended in 201 steps. total_reward=-200.0
#
#  Episode #86 ended in 201 steps. total_reward=-200.0
#
#  Episode #87 ended in 201 steps. total_reward=-200.0
#
#  Episode #88 ended in 201 steps. total_reward=-200.0
#
#  Episode #89 ended in 201 steps. total_reward=-200.0
#
#  Episode #90 ended in 201 steps. total_reward=-200.0
#
#  Episode #91 ended in 201 steps. total_reward=-200.0
#
#  Episode #92 ended in 201 steps. total_reward=-200.0
#
#  Episode #93 ended in 201 steps. total_reward=-200.0

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True
